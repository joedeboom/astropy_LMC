# %%
import dataset_utils
import data_utils

# %%
#  Define name of the dataset
dataset = 'test'

#  Define bbox scale factor
scale_factor = 2

#  Create shift images?
shift = False

#  Define image shuffle seed. If None, images will not be shuffled
shuffle = 100

#  Define radio scaling factor
radio_factor = 25030

#  Define halpha scaling factor
halpha_factor = 1

#  Initialize dataset
dataset_utils.init(name=dataset, scale_factor=scale_factor, shift=shift, shuffle=shuffle, radio_factor=radio_factor, halpha_factor=halpha_factor)
# Out:
# Creating directories...
# Generating image...
# Generating polygons and labels...
# Generating bounding boxes...
# Generating the annotation array...
# 100%|██████████| 386/386 [08:29<00:00,  1.32s/it]
# Saved ann.npy
# Saved ann.png
# Looping training bboxes...
# 100%|██████████| 309/309 [00:03<00:00, 86.01it/s]
# Looping validation bboxes...
# 100%|██████████| 77/77 [00:01<00:00, 69.26it/s]

# %%
#  Transforms available are 'clip99', 'normalize', 'sqrtstrecht', logstretch', 'zscale'
#  Include 'separate' flag to process transforms separately for each channel

dataset = 'test'
transforms = ['normalize','clip99']
data_utils.inspect_dataset(dataset, transforms=transforms)
# Out:
# DATASET/sammy/data/my_dataset/img/train/1.npy
#
#
# Initial data stats
# +-------------+-----------+-------------+
# | Statistic   |     Radio |      Halpha |
# +=============+===========+=============+
# | Avg         |  37.4426  |   0.749027  |
# +-------------+-----------+-------------+
# | Std         |  62.5159  |   4.0964    |
# +-------------+-----------+-------------+
# | Min         |  -5.72159 |  -3.02625   |
# +-------------+-----------+-------------+
# | 10          |   2.44221 |   0.0148251 |
# +-------------+-----------+-------------+
# | 25          |   4.42877 |   0.105328  |
# +-------------+-----------+-------------+
# | 50          |   6.76844 |   0.381818  |
# +-------------+-----------+-------------+
# | 75          |  18.8131  |   1.00348   |
# +-------------+-----------+-------------+
# | 90          | 154.445   |   1.99117   |
# +-------------+-----------+-------------+
# | 99          | 229.903   |   3.49645   |
# +-------------+-----------+-------------+
# | Max         | 301.949   | 561.062     |
# +-------------+-----------+-------------+
#
# Applying 'clip99' on channels together
# +-------------+-----------+-------------+
# | Statistic   |     Radio |      Halpha |
# +=============+===========+=============+
# | Avg         |  37.407   |   0.735707  |
# +-------------+-----------+-------------+
# | Std         |  62.3847  |   2.53822   |
# +-------------+-----------+-------------+
# | Min         |  -5.72159 |  -3.02625   |
# +-------------+-----------+-------------+
# | 10          |   2.44221 |   0.0148251 |
# +-------------+-----------+-------------+
# | 25          |   4.42877 |   0.105328  |
# +-------------+-----------+-------------+
# | 50          |   6.76844 |   0.381818  |
# +-------------+-----------+-------------+
# | 75          |  18.8131  |   1.00348   |
# +-------------+-----------+-------------+
# | 90          | 154.445   |   1.99117   |
# +-------------+-----------+-------------+
# | 99          | 229.903   |   3.49645   |
# +-------------+-----------+-------------+
# | Max         | 252.995   | 252.995     |
# +-------------+-----------+-------------+
#
# Applying 'normalize' on channels together
# +-------------+-----------+------------+
# | Statistic   |     Radio |     Halpha |
# +=============+===========+============+
# | Avg         | 0.166702  | 0.0249589  |
# +-------------+-----------+------------+
# | Std         | 0.241132  | 0.00981081 |
# +-------------+-----------+------------+
# | Min         | 0         | 0.0104181  |
# +-------------+-----------+------------+
# | 10          | 0.031555  | 0.0221726  |
# +-------------+-----------+------------+
# | 25          | 0.0392335 | 0.0225224  |
# +-------------+-----------+------------+
# | 50          | 0.0482769 | 0.0235911  |
# +-------------+-----------+------------+
# | 75          | 0.0948322 | 0.025994   |
# +-------------+-----------+------------+
# | 90          | 0.619082  | 0.0298116  |
# +-------------+-----------+------------+
# | 99          | 0.910743  | 0.0356299  |
# +-------------+-----------+------------+
# | Max         | 1         | 1          |
# +-------------+-----------+------------+
#
# Normilzation bounds:
# {
#     "radio": {
#         "min": -5.721585273742676,
#         "max": 252.9949188232422
#     },
#     "halpha": {
#         "min": -5.721585273742676,
#         "max": 252.9949188232422
#     }
# }
#
# Region of interest average pixel value:
# {
#     "Radio": {
#         "HII": 0.34804582595825195,
#         "SNR": NaN
#     },
#     "Halpa": {
#         "HII": 0.027780894190073013,
#         "SNR": NaN
#     }
# }
# Press enter for next image, 'p' for previous image, or enter image id. 'q' to quitq
